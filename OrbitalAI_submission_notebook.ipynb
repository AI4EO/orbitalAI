# %% [markdown]
# # Name of your solution
#
# ## Name of your team

# %% [markdown]
# ## 1. Executive summary
# *Provide a summary (a few paragraphs)ß describing the problem your ML applications aims to solve and how your solution achieves that*

# %% [markdown]
# ## 2. Imports and code dependencies
# *Provide a list of Python dependencies and custom code required to reproduce the results*

# %%
# Imports and code dependencies:

# %% [markdown]
# ## 3. Input/Output data and example training labels (if applicable)
#
# - *Provide an example of input image data. If a different simulation process was employed than the one provided, the difference should be stated clearly.*
#
# - *Provide an example of training labels used, with details about where their provenance, and spatio-temporal coverage.*
#
# - *What image format does the model expect? E.g. PNG, FITS, GeoTIFF?*
#
# - *What input image size in pixels does the model expect? (e.g. 256*256)*
#
# - *What bit depth are the input images? E.g. uint8_t, float32 etc. This can be found through opening the image using the programme ImageJ.*
#
# - *How many channels are present in the input images? E.g. RGB = 3 channels*
#
# - *If the output of your model is an image, what is its bit depth?*
#
# - *What data range is expected by the model? E.g. between (-1 - 1) or (0 - 1).*
#
# - *What normalisation do you perform to transform this data to be within this range?*
#
# - *If you are applying scale/mean values please note them.*
#
# - *What is the output of your model? E.g. an image, coordinates etc.*
#
# - *What data format/range is the output of the model? E.g. between (-1 - 1) or (0 - 1).*
#
# - *Do you perform any post processing on the output of your model? E.g. normalise to between 0-255.*

# %% [markdown]
# ## 4. Description of ML algorithm and training strategies
#
# - *Provide a few paragraphs with images about the ML algorithm and the training strategy employed.*
#
# - *If transfer learning was used when developing your model, what model was used as the base model? E.g. Mobilenet, YoloV5, ...*

# %% [markdown]
# ## 5. Inference step
#
# - *Provide your code showing how inference is executed given the input image.*
#
# - *Provide a visual example and format of the output. A diagram is provided below as an example.*
#
#
# ![subm_template_image.png](attachment:subm_template_image.png)
#
# - *Provide information on the computational cost (RAM/CPUs currently used).*

# %% [markdown]
# ## 6.    Validation
#
# - *Provide a few paragraphs describing how the algorithm was validated, which metrics were used and what were the scores achieved.*
#
# - *Present known issues / limitations of your solution (i.e. spatial / temporal generalization, ...)*
